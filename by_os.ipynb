# %%
import pandas as pd

# %%
raw = pd.read_csv("by_os.csv", comment='#', thousands=',')
raw
# Out:
#     Operating System    Users  New Users  Sessions Bounce Rate  \
# 0            Windows   64,419    63423.0   94479.0      76.00%
# 1          Macintosh   47,523    47565.0   81651.0      69.69%
# 2              Linux   16,427    16416.0   25164.0      79.78%
# 3                iOS   13,128    13192.0   15739.0      81.60%
# 4            Android    8,597     8539.0   10771.0      70.66%
# ..               ...      ...        ...       ...         ...
# 373         12/28/22      399        NaN       NaN         NaN
# 374         12/29/22      394        NaN       NaN         NaN
# 375         12/30/22      342        NaN       NaN         NaN
# 376         12/31/22      271        NaN       NaN         NaN
# 377              NaN  207,402        NaN       NaN         NaN
#
#      Pages / Session Avg. Session Duration Goal Conversion Rate  \
# 0               1.52              00:01:30                0.00%
# 1               1.75              00:02:06                0.00%
# ...

# %% [markdown]
# Number of page views per day begins after the 500 pages so cut dataframe:

# %%
pages = raw.iloc[:10].copy()
pages
# Out:
#   Operating System   Users  New Users  Sessions Bounce Rate  Pages / Session  \
# 0          Windows  64,419    63423.0   94479.0      76.00%             1.52
# 1        Macintosh  47,523    47565.0   81651.0      69.69%             1.75
# 2            Linux  16,427    16416.0   25164.0      79.78%             1.43
# 3              iOS  13,128    13192.0   15739.0      81.60%             1.27
# 4          Android   8,597     8539.0   10771.0      70.66%             1.31
# 5        (not set)   3,597     3597.0    3603.0      99.44%             1.53
# 6        Chrome OS     366      364.0     423.0      74.00%             1.75
# 7          FreeBSD       2        2.0       2.0     100.00%             1.00
# 8          OpenBSD       2        2.0       2.0       0.00%             2.00
# 9       BlackBerry       1        1.0       1.0     100.00%             1.00
#
#   Avg. Session Duration Goal Conversion Rate  Goal Completions Goal Value
# ...

# %%
pages["Users"] = pages["Users"].str.replace(",", "").astype('int32')
pages["New Users"] = pages["New Users"].astype('int32')
pages["Sessions"] = pages["Sessions"].astype('int32')

# %%
pages.Users.sum()
# Out:
# 154062

# %%
pages.Sessions.sum()
# Out:
# 231835

# %%
38055/pages.Users.sum()
# Out:
# 0.24701094364606457

# %%
c=pages["Users"].sum()

# %%
37654/c
# Out:
# 0.24440809544209474

# %%
28705/c
# Out:
# 0.18632109150861342

# %%
12007/c
# Out:
# 0.07793615557373006

# %%
9452/c
# Out:
# 0.061351923251677896

# %%
6152/c
# Out:
# 0.03993197543845984

# %%
pages.describe()
# Out:
#               Users    New Users      Sessions  Pages / Session  \
# count     10.000000     10.00000     10.000000        10.000000
# mean   15406.200000  15310.10000  23183.500000         1.456000
# std    22518.892319  22287.05127  35321.599505         0.325037
# min        1.000000      1.00000      1.000000         1.000000
# 25%       93.000000     92.50000    107.250000         1.280000
# 50%     6097.000000   6068.00000   7187.000000         1.475000
# 75%    15602.250000  15610.00000  22807.750000         1.695000
# max    64419.000000  63423.00000  94479.000000         2.000000
#
#        Goal Completions
# count              10.0
# mean                0.0
# std                 0.0
# min                 0.0
# 25%                 0.0
# 50%                 0.0
# 75%                 0.0
# max                 0.0

# %%
df = pages.drop(columns=["Goal Conversion Rate", "Goal Completions", "Goal Value"])

# %%
df
# Out:
#   Operating System  Users  New Users  Sessions Bounce Rate  Pages / Session  \
# 0          Windows  64419      63423     94479      76.00%             1.52
# 1        Macintosh  47523      47565     81651      69.69%             1.75
# 2            Linux  16427      16416     25164      79.78%             1.43
# 3              iOS  13128      13192     15739      81.60%             1.27
# 4          Android   8597       8539     10771      70.66%             1.31
# 5        (not set)   3597       3597      3603      99.44%             1.53
# 6        Chrome OS    366        364       423      74.00%             1.75
# 7          FreeBSD      2          2         2     100.00%             1.00
# 8          OpenBSD      2          2         2       0.00%             2.00
# 9       BlackBerry      1          1         1     100.00%             1.00
#
#   Avg. Session Duration
# 0              00:01:30
# 1              00:02:06
# 2              00:01:22
# 3              00:00:49
# ...

# %%
pd.set_option('display.max_rows', 300)

# %%
df[:10]
# Out:
#   Operating System  Users  New Users  Sessions Bounce Rate  Pages / Session  \
# 0          Windows  64419      63423     94479      76.00%             1.52
# 1        Macintosh  47523      47565     81651      69.69%             1.75
# 2            Linux  16427      16416     25164      79.78%             1.43
# 3              iOS  13128      13192     15739      81.60%             1.27
# 4          Android   8597       8539     10771      70.66%             1.31
# 5        (not set)   3597       3597      3603      99.44%             1.53
# 6        Chrome OS    366        364       423      74.00%             1.75
# 7          FreeBSD      2          2         2     100.00%             1.00
# 8          OpenBSD      2          2         2       0.00%             2.00
# 9       BlackBerry      1          1         1     100.00%             1.00
#
#   Avg. Session Duration
# 0              00:01:30
# 1              00:02:06
# 2              00:01:22
# 3              00:00:49
# ...

# %%
x = list(df.columns)
x
# Out:
# ['Operating System',
#  'Users',
#  'New Users',
#  'Sessions',
#  'Bounce Rate',
#  'Pages / Session',
#  'Avg. Session Duration']

# %%
x[5] = "P/S"
x[6] = "ASD"

# %%
df.columns = x

# %%
ed_table = df[:100].reset_index(drop=True).fillna('')
ed_table.index = range(1, ed_table.shape[0] + 1)
ed_table.to_latex('by_os.tex', longtable=True)
# Out:
# /var/folders/x5/f0v08d0968dfbr7r4fj55ln80000gn/T/ipykernel_26072/4164442345.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   ed_table.to_latex('by_os.tex', longtable=True)

# %%
ed_table
# Out:
#    Operating System  Users  New Users  Sessions Bounce Rate   P/S       ASD
# 1           Windows  64419      63423     94479      76.00%  1.52  00:01:30
# 2         Macintosh  47523      47565     81651      69.69%  1.75  00:02:06
# 3             Linux  16427      16416     25164      79.78%  1.43  00:01:22
# 4               iOS  13128      13192     15739      81.60%  1.27  00:00:49
# 5           Android   8597       8539     10771      70.66%  1.31  00:01:11
# 6         (not set)   3597       3597      3603      99.44%  1.53  00:00:06
# 7         Chrome OS    366        364       423      74.00%  1.75  00:01:26
# 8           FreeBSD      2          2         2     100.00%  1.00  00:00:00
# 9           OpenBSD      2          2         2       0.00%  2.00  00:07:16
# 10       BlackBerry      1          1         1     100.00%  1.00  00:00:00

# %%
total=ed_table["Users"].sum()

# %%
round(100*8597/total)
# Out:
# 6
